# %%
from redfin_scraper import RedfinScraper
import pandas as pd

zip_codes = pd.read_csv('data/zip_code_database.csv')

# %%
zip_codes
# Out:
#          zip      type  decommissioned primary_city acceptable_cities  \
# 0        501    UNIQUE               0   Holtsville               NaN
# 1        544    UNIQUE               0   Holtsville               NaN
# 2        601  STANDARD               0     Adjuntas               NaN
# 3        602  STANDARD               0       Aguada               NaN
# 4        603  STANDARD               0    Aguadilla             Ramey
# ...      ...       ...             ...          ...               ...
# 42730  99926    PO BOX               0   Metlakatla               NaN
# 42731  99927    PO BOX               0  Point Baker               NaN
# 42732  99928    PO BOX               0    Ward Cove               NaN
# 42733  99929    PO BOX               0     Wrangell               NaN
# 42734  99950    PO BOX               0    Ketchikan  Edna Bay, Kasaan
#
#                                      unacceptable_cities state  \
# ...

# %%
scraper = RedfinScraper()

# %%
scraper.setup(zip_database_path="data/zip_code_database.csv")

# %%
new_df = scraper.scrape(city_states=['Scotts Valley, CA'])

# %%
new_df[0]
# Out:
#                 SALE TYPE  SOLD DATE              PROPERTY TYPE  \
# 0             MLS Listing        NaN   Mobile/Manufactured Home
# 1             MLS Listing        NaN  Single Family Residential
# 2             MLS Listing        NaN  Single Family Residential
# 3             MLS Listing        NaN  Single Family Residential
# 4             MLS Listing        NaN  Single Family Residential
# ..                    ...        ...                        ...
# 68  New Construction Home        NaN  Single Family Residential
# 69  New Construction Home        NaN  Single Family Residential
# 70  New Construction Plan        NaN                  Townhouse
# 71  New Construction Plan        NaN  Single Family Residential
# 72  New Construction Plan        NaN  Single Family Residential
#
#                   ADDRESS           CITY STATE OR PROVINCE ZIP OR POSTAL CODE  \
# 0   2395 Delaware St #194     Santa Cruz                CA              95060
# ...

# %%
new_df = new_df[0]

new_df.to_csv('data/house_listing_sample.csv')

# %%
client.below_the_fold(property_id)
# Out:
# {'version': 480,
#  'errorMessage': 'Success',
#  'resultCode': 0,
#  'payload': {'amenitiesInfo': {'provider': '',
#    'superGroups': [{'types': [21],
#      'amenityGroups': [{'groupTitle': 'Bathroom Information',
#        'referenceName': 'Bathroom Information',
#        'amenityEntries': [{'amenityName': '# of Full Baths',
#          'referenceName': 'FULL_BATHS',
#          'accessLevel': 1,
#          'displayLevel': 1,
#          'amenityValues': ['3']}]},
#       {'groupTitle': 'Fireplace Information',
#        'referenceName': 'Interior Features',
#        'amenityEntries': [{'amenityName': '# of Fireplaces',
#          'referenceName': 'NUMBER_OF_FIREPLACES',
#          'accessLevel': 1,
#          'displayLevel': 1,
#          'amenityValues': ['2']},
#         {'referenceName': 'FIREPLACE_INDICATOR',
#          'accessLevel': 1,
#          'displayLevel': 1,
#          'amenityValues': ['Has Fireplace']}]},
#       {'groupTitle': 'Room Information',
# ...
